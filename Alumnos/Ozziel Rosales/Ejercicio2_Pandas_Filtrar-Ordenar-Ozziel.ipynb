# %% [markdown]
# # Eurocopa 2012

# %% [markdown]
# Esta vez vamos a importar los datos directo desde internet
# ### 1. Importa las librerías necesarias

# %%
import pandas as pd
import numpy as pn

# %% [markdown]
# ### 2. Importa la base de datos desde esta [liga](https://github.com/kis/eurocups/blob/master/assets/football/Euro%202012/Euro%202012%20stats%20TEAM.csv) y asigna el DataFrame a la variable 'euro12'

# %%
euro12 = pd.read_csv('https://raw.githubusercontent.com/kis/eurocups/master/assets/football/Euro%202012/Euro%202012%20stats%20TEAM.csv', sep=",")

# %% [markdown]
# ### 3. Selecciona sólo la columna con los Goles

# %%
euro12["Goals"]
# Out:
# 0      4
# 1      4
# 2      4
# 3      5
# 4      3
# 5     10
# 6      5
# 7      6
# 8      2
# 9      2
# 10     6
# 11     1
# 12     5
# 13    12
# 14     5
# 15     2
# Name: Goals, dtype: int64

# %% [markdown]
# ### 4. ¿Cuántos equipos participaron en la Eurocopa de 2012?

# %%
len(euro12)
# Out:
# 16

# %% [markdown]
# ### 5. ¿Cuál es el número de columnas en la base de datos?

# %%
len(euro12.columns)
# Out:
# 35

# %% [markdown]
# ### 6. Muestra sólo las columnas Team, Yellow Cards y Red Cards y asignalas a un nuevo DataFrame llamado disciplina

# %%
disciplina = euro12[["Team", "Yellow Cards", "Red Cards"]]
disciplina
# Out:
#                    Team  Yellow Cards  Red Cards
# 0               Croatia             9          0
# 1        Czech Republic             7          0
# 2               Denmark             4          0
# 3               England             5          0
# 4                France             6          0
# 5               Germany             4          0
# 6                Greece             9          1
# 7                 Italy            16          0
# 8           Netherlands             5          0
# 9                Poland             7          1
# 10             Portugal            12          0
# 11  Republic of Ireland             6          1
# 12               Russia             6          0
# 13                Spain            11          0
# 14               Sweden             7          0
# 15              Ukraine             5          0

# %% [markdown]
# ### 7. En este nuevo DataFrame (llamado 'disciplina') ordena los equipos por Red Cards primero y luego por Yellow Cards

# %%
disciplina[["Red Cards", "Yellow Cards","Team"]]
# Out:
#     Red Cards  Yellow Cards                 Team
# 0           0             9              Croatia
# 1           0             7       Czech Republic
# 2           0             4              Denmark
# 3           0             5              England
# 4           0             6               France
# 5           0             4              Germany
# 6           1             9               Greece
# 7           0            16                Italy
# 8           0             5          Netherlands
# 9           1             7               Poland
# 10          0            12             Portugal
# 11          1             6  Republic of Ireland
# 12          0             6               Russia
# 13          0            11                Spain
# 14          0             7               Sweden
# 15          0             5              Ukraine

# %% [markdown]
# ### 8. Calcula el promedio de Yellow Cards para un equipo de la Euro

# %%
disciplina["Yellow Cards"].mean()
# Out:
# 7.4375

# %% [markdown]
# ### 9. Filtra de tu DataFrame Euro aquellos equipos que anotaron más de 6 goles

# %%
euro12[euro12['Goals']>6]['Team']
# Out:
# 5     Germany
# 13      Spain
# Name: Team, dtype: object

# %% [markdown]
# ### 10. Selecciona los equipos que comienzan con 'G' (Tip: Investiga el método str.startswith() )

# %%
#K = pd.Series(['Gat', 'Bear', 'cat'])
#euro12.str.startswith('G')
euro12[euro12["Team"].str.startswith('G')]["Team"]
# Out:
# 5    Germany
# 6     Greece
# Name: Team, dtype: object

# %% [markdown]
# ### 11. Selecciona las primeras 7 columnas

# %%
euro12.iloc[:,:7]
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# 13                Spain     12               42                33
# 14               Sweden      5               17                19
# 15              Ukraine      2                7                26
#
#    Shooting Accuracy % Goals-to-shots  Total shots (inc. Blocked)
# 0              51.9%            16.0%                          32
# 1              41.9%            12.9%                          39
# 2              50.0%            20.0%                          27
# 3              50.0%            17.2%                          40
# 4              37.9%             6.5%                          65
# 5              47.8%            15.6%                          80
# 6              30.7%            19.2%                          32
# 7              43.0%             7.5%                         110
# 8              25.0%             4.1%                          60
# 9              39.4%             5.2%                          48
# 10             34.3%             9.3%                          82
# 11             36.8%             5.2%                          28
# 12             22.5%            12.5%                          59
# 13             55.9%            16.0%                         100
# 14             47.2%            13.8%                          39
# 15             21.2%             6.0%                          38

# %% [markdown]
# ### 12. Selecciona todas las columnas excepto las últimas 3

# %%
f=len(euro12.columns)
j=euro12.iloc[:,:f-3]
j
#len(j.columns)
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# 13                Spain     12               42                33
# 14               Sweden      5               17                19
# 15              Ukraine      2                7                26
#
#    Shooting Accuracy % Goals-to-shots  Total shots (inc. Blocked)  \
# 0              51.9%            16.0%                          32
# 1              41.9%            12.9%                          39
# 2              50.0%            20.0%                          27
# 3              50.0%            17.2%                          40
# 4              37.9%             6.5%                          65
# 5              47.8%            15.6%                          80
# 6              30.7%            19.2%                          32
# 7              43.0%             7.5%                         110
# 8              25.0%             4.1%                          60
# 9              39.4%             5.2%                          48
# 10             34.3%             9.3%                          82
# 11             36.8%             5.2%                          28
# 12             22.5%            12.5%                          59
# 13             55.9%            16.0%                         100
# 14             47.2%            13.8%                          39
# 15             21.2%             6.0%                          38
#
#     Hit Woodwork  Penalty goals  Penalties not scored    ...      \
# 0              0              0                     0    ...
# 1              0              0                     0    ...
# 2              1              0                     0    ...
# 3              0              0                     0    ...
# 4              1              0                     0    ...
# 5              2              1                     0    ...
# 6              1              1                     1    ...
# 7              2              0                     0    ...
# 8              2              0                     0    ...
# 9              0              0                     0    ...
# 10             6              0                     0    ...
# 11             0              0                     0    ...
# 12             2              0                     0    ...
# 13             0              1                     0    ...
# 14             3              0                     0    ...
# 15             0              0                     0    ...
#
#     Clean Sheets  Blocks  Goals conceded Saves made  Saves-to-shots ratio  \
# 0              0      10               3         13                 81.3%
# 1              1      10               6          9                 60.1%
# 2              1      10               5         10                 66.7%
# 3              2      29               3         22                 88.1%
# 4              1       7               5          6                 54.6%
# 5              1      11               6         10                 62.6%
# 6              1      23               7         13                 65.1%
# 7              2      18               7         20                 74.1%
# 8              0       9               5         12                 70.6%
# 9              0       8               3          6                 66.7%
# 10             2      11               4         10                 71.5%
# 11             0      23               9         17                 65.4%
# 12             0       8               3         10                 77.0%
# 13             5       8               1         15                 93.8%
# 14             1      12               5          8                 61.6%
# 15             0       4               4         13                 76.5%
#
#     Fouls Won  Fouls Conceded  Offsides  Yellow Cards  Red Cards
# 0          41              62         2             9          0
# 1          53              73         8             7          0
# 2          25              38         8             4          0
# 3          43              45         6             5          0
# 4          36              51         5             6          0
# 5          63              49        12             4          0
# 6          67              48        12             9          1
# 7         101              89        16            16          0
# 8          35              30         3             5          0
# 9          48              56         3             7          1
# 10         73              90        10            12          0
# 11         43              51        11             6          1
# 12         34              43         4             6          0
# 13        102              83        19            11          0
# 14         35              51         7             7          0
# 15         48              31         4             5          0
#
# [16 rows x 32 columns]

# %% [markdown]
# ### 13. Muestra únicamente la columna Shooting Accuracy para England, Italy y Russia

# %%
#euro12[euro12['Goals']>6]['Team']
  #euro12[euro12['Team']=='Italy']['Team']+
    #euro12[euro12['Team']=='Russia']['Team']


euro12[euro12["Team"].isin(['England','Italy','Russia'])][["Team","Shooting Accuracy"]]
# Out:
#        Team Shooting Accuracy
# 3   England             50.0%
# 7     Italy             43.0%
# 12   Russia             22.5%
